# %% [markdown]
# <a href="https://colab.research.google.com/github/atalpandeyy/Anudip_PythonProgramms/blob/main/Class%20work..%20exceptionhandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:

  numl = float(input("Enter first number: "))

  num2= float(input("Enter second number: "))

  print("--

  -")

  print("On Dividing", num1, "by", num2)

  print("Quotient: ", (num1/num2))

  print("-----

  -")

  except ValueError:

  print("Unexpected data type")

  except ZeroDivisionError:

  print("Unable to divide by 0")

  else:

  print("-------------")

  -")

  finally:

  print("--- Program Executed---")
